# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from urllib.request import urlretrieve

# %%
urlretrieve('https://www.analyticsinsight.net/wp-content/uploads/2021/01/Analytics-1024x622.jpeg'
            , 'chart.jpg');

# %%
from PIL import Image
# pyton image libary =PIL

# %%
img =Image.open('chart.jpg')

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
plt.imshow(img);
# for showing the image

# %%
img_array= np.array(img)

# %%
img_array.shape
# Out:
# (622, 1024, 3)

# %%
img_array
# Out:
# array([[[ 1,  2,  7],
#         [ 1,  2,  7],
#         [ 1,  2,  7],
#         ...,
#         [ 0,  5, 39],
#         [ 0,  5, 39],
#         [ 0,  5, 39]],
#
#        [[ 1,  2,  7],
#         [ 1,  2,  7],
#         [ 1,  2,  7],
#         ...,
#         [ 0,  5, 39],
#         [ 0,  5, 39],
#         [ 0,  5, 39]],
#
#        [[ 1,  2,  7],
#         [ 1,  2,  7],
#         [ 1,  2,  7],
#         ...,
#         [ 0,  5, 39],
#         [ 0,  5, 39],
#         [ 0,  5, 39]],
#
#        ...,
#
#        [[ 2, 55, 95],
#         [ 2, 55, 95],
#         [ 1, 54, 94],
#         ...,
#         [ 0,  6, 40],
#         [ 0,  6, 40],
#         [ 0,  6, 40]],
#
#        [[ 2, 55, 95],
#         [ 2, 55, 95],
#         [ 2, 54, 94],
#         ...,
#         [ 0,  6, 40],
#         [ 0,  6, 40],
#         [ 0,  6, 40]],
#
#        [[ 3, 55, 95],
#         [ 3, 55, 95],
#         [ 2, 54, 94],
#         ...,
#         [ 0,  6, 40],
#         [ 0,  6, 40],
#         [ 0,  6, 40]]], dtype=uint8)

# %%
plt.grid(False)
plt.title('A data science wave')
plt.axis('off')
plt.imshow(img);

# We can turn off the axes & grid lines 
# and show a title using the relevant functions.

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(img_array[200:400,600:800]);
# displaying part of image
